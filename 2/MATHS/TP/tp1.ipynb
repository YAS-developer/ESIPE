# %% [markdown]
# <div style="text-align: left">
#     <p><strong>2024-2025</strong></p>
#     <p><strong>ESIPE Informatique</strong></p>
#     <p><strong>F.-X. Vialard et M.-Y. Gueddari</strong></p>
# </div>
#
# <div style="text-align: center">
#     <h1>TP 2 - Probabilités et statistiques </h1>
# </div>
#
# <div style="text-align: center"><font color="red"> Attention : Veuillez faire attention à la qualité de vos raisonnements, à la rédaction et à la lisibilité du code.</font></div>

# %% [markdown]
# Ce notebook est décomposé en trois parties:
# - **Partie <span style="font-family: 'Times New Roman';">I</span>**: Introduction à Python et à certaines librairies importantes en probabilités et en statistiques. Cette partie n'est pas notée.
# - **Partie <span style="font-family: 'Times New Roman';">II</span>**: Le coeur de ce TP, on étudiera la méthode de Monte-Carlo. Cette partie est notée.
# - **Partie <span style="font-family: 'Times New Roman';">III</span>**: Dans cette partie on étudiera les intervalles de confiance. Cette partie est notée.

# %% [markdown]
# ## Partie <span style="font-family: 'Times New Roman';">I</span> - Introduction rapide à Python (Tuto)

# %% [markdown]
# - **Python** est un langage multiusage qui est libre et qui peut être utilisé comme substitut à matlab, notamment en utilisant la librairie numpy. C'est d'ailleurs un langage de plus en plus utilisé (dans les trois premiers utilisés).
# - **Jupyter notebook** est une interface qui permet d'écrire du code, de le faire exécuter, d'écrire du texte. C'est ce qu'on utilise maintenant pour le TP.
# - Pour utiliser python et les notebooks, on conseille d'installer la distribution de python [anaconda](https://www.anaconda.com/download) avec python 3.

# %% [markdown]
# ### <span style="font-family: 'Times New Roman';">I</span>.1 - Eléments de base en Python

# %% [markdown]
# #### <span style="font-family: 'Times New Roman';">I</span>.1.1 - Affectation de Variables

# %% [markdown]
# Pour affecter la valeur "10" à une variables "a" en utilise la syntaxe:
# ~~~py
# >>> a = 10
# ~~~
# Pour afficher la valeur de a en utilise la fonction `print`:
# ~~~py
# >>> print(a)
# 10
# ~~~

# %% [markdown]
# Exécuter les cellules suivantes pour voir le résultat.

# %%
# Affection de variables
a = 10
b = 5.2
message = "Bonjour, le monde!"

# %%
# Affichage des variables
print(f"a = {a}, b = {b}, message = {message}")

# %% [markdown]
# #### <span style="font-family: 'Times New Roman';">I</span>.1.2 - Les boucles en Python
# Il existe deux types de boucles en python: `for` et `while`.

# %% [markdown]
# Pour balayer tous les nombres de $0$ jusqu'à $4$, calculer leurs carrés et les afficher on utilise le code suivant:

# %%
# Boucle for
for i in range(5):
    carre = i**2
    print(carre)

# %% [markdown]
# Pour faire la même chose à l'aide de la boucle `while`, on initialise un compteur `counter` à $0$, et on même la condition d'arrêt suivante: `counter < 5` dans la boucle while. La boucle s'arrête alors dès que le compteur dépasse $5$.

# %%
# Boucle while
counter = 0
while counter < 5:
    carre = counter**2
    print(carre)
    counter += 1 # on incrémente le compteur.

# %% [markdown]
# #### <span style="font-family: 'Times New Roman';">I</span>.1.3 - Les conditions en Python

# %% [markdown]
# Etant donné une variable x, on veut renvoyer le texte *x est supérieur à 10.* si x>10 et *x est inférieur à 10.* si x <= 10.

# %%
# Conditions
x = 15

if x > 10:
    print("x est supérieur à 10.")
else:
    print("x est inférieur à 10.")

# %% [markdown]
# **<font color="red">Question: </font>** Essayer avec x=4.

# %% [markdown]
# #### <span style="font-family: 'Times New Roman';">I</span>.1.4 - Les fonctions en Python

# %% [markdown]
# Pour créer une fonction qui s'appelle `add_numbers` qui prend deux arguments x et y et qui renvoie leur somme on utilise le code suivant.

# %%
# Définition de la fonction
def add_numbers(x, y):
    return x + y

# %% [markdown]
# Maintenant on veut appeler la fonction pour calculer la somme de $3$ et $7$.

# %%
# Appel de la fonction
result = add_numbers(3, 7)
print("Résultat de la fonction add_numbers(3, 7):", result)

# %% [markdown]
# **<font color="red">Question: </font>** Ecrire une fonction qui prend en argument deux valeurs `n` et `p`, qui calcule la somme des inverses des élements de $1$ à $n$, i.e. $\sum_{i=1}^n \frac{1}{i}$ et qui renvoie `True` si cette valeur est supérieur à `p` et `False` sinon.

# %% [markdown]
# *Indication:* il faut faire une boucle `for` qui commence de $1$ et qui termine à $n+1$.
# ~~~py
# >>> for i in range(1, n+1):
#     # à compléter
# ~~~

# %% [markdown]
# #### <span style="font-family: 'Times New Roman';">I</span>.1.5 - Les listes en Python

# %% [markdown]
# Pour déclarer une liste `L` qui contient les élements 6, -4, 8, et 10 dans cet ordre on utilise la syntaxe suivante:
# ~~~py
# >>> L = [6, -4, 8, 10]
# ~~~
# Pour accéder à la 2ème valeur de la liste (i.e. le `-4`) on prend élément d'indice 1 dans la liste.
# ~~~py
# >>> a = L[1]
# >>> print(a)
# -4
# ~~~
# Pour ajouter le nombre `999` dans la liste `L` on utilise la méthode `.append()`.
# ~~~py
# >>> L.append(999)
# >>> print(L)
# [6, -4, 8, 10, 999]
# ~~~
# Pour modifier le 3ème élément de la liste (dans l'élement d'indice 2) et le remplacer par 35 on utilise le code suivant:
# ~~~py
# >>> L[2] = 35
# >>> print(L)
# [6, -4, 35, 10, 999]
# ~~~
# Pour initialiser une liste vide et la remplire par les carrés des nombres de $1$ jusqu'à $10$ on utilise le code suivant:
# ~~~py
# >>> L = []
# >>> for i in range(1, 11):
# >>>     carre = i**2
# >>>     L.append(carre)
# >>> print(L)
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# ~~~
# Pour caluler la taille d'une liste donnée on utilise la méthode `len()`.
# ~~~py
# >>> L = [1,4,6,7]
# >>> print(len(L))
# 4
# ~~~
# Pour calculer les carrés des éléments de la liste `[1,4,6,7]` et les afficher on peut utiliser une boucle `for` directement sur les éléments de la liste.
# ~~~py
# >>> L = [1,4,6,7]
# >>> for i in L:
# >>>     carre = i**2
# >>>     print(carre)
# 1
# 16
# 36
# 49
#
# ~~~
# Pour calculer la somme des éléments d'une liste L on utilise les méthode `sum(L)`.
# ~~~py
# >>> L = [1, 4, 6, 7]
# >>> s = sum(L)
# >>> print(s)
# 18
# ~~~
# Pour concaténer deux liste `A` et `B` on utilise la syntaxe `A+B`. Par exemple
# ~~~~py
# >>> A = [1,4,5]
# >>> B = [4,6,0]
# >>> L = A+B
# >>> print(L)
# [1, 4, 5, 4, 6, 0]
# ~~~

# %% [markdown]
# **<font color="red">Question: </font>** Copier les codes présentés ci-dessous dans les cellules suivantes et les éxecuter. Vérifier que à chaque fois vous obtenez le bon résultat.
#
# *Remarque: Pour ajouter une nouvelle cellule de code, vous pouvez cliquer sur le symbole `+` en haut à gauche de cette page.*

# %%
def add_numbers(x, y):
    return x + y

result = add_numbers(3, 7)
print("Résultat de la fonction add_numbers(3, 7):", result)
# Out:
# Résultat de la fonction add_numbers(3, 7): 10

# %%
A = [1,4,5]
B = [4,6,0]
L = A+B
print(L)
# Out:
# [1, 4, 5, 4, 6, 0]

# %%
L = []
for i in range(1, 11):
    carre = i**2
    L.append(carre)
print(L)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# ### <span style="font-family: 'Times New Roman';">I</span>.2 - Les librairies du calcul scientifique: `Numpy`, `Scipy` et `Matplotlib`

# %% [markdown]
# Dans le cadre de ce TP, nous aurons besoin de quelques librairies du calcul numérique scientifique afin d'effectuer facilement plusieurs opérations. Nous utiliserons aussi une librairie qui nous permettra de tracer les figures graphique.

# %%
# import des librairies scientifiques numpy et scipy, et pylab pour tracer des graphiques.

import numpy as np # j'importe la librairie pour le calcul numérique et je la nomme "np"
import scipy as sp # j'importe la librairie pour l'analyse scientifique et je la nomme "sp".
import matplotlib.pyplot as plt # j'importe la librairie pour la visualisation de graphiques et je la nomme "plt"

# pour exécuter la cellule, faire "shift+entrée".

# %% [markdown]
# Pour avoir plus d'informations sur les librairies, vous pouvez consulter les documentations: [Numpy](https://numpy.org/), [Scipy](https://scipy.org/) et [Matplotlib](https://matplotlib.org/).

# %% [markdown]
# Pour créer un vecteur de taille $10$ qui contient les élements de $0$ jusqu'à $9$ on utilise `arange()` de la librairie numpy.

# %%
# Utiliser numpy pour faire des calculs sur des vecteurs.
a = np.arange(10)
print(a)

# %% [markdown]
# Grâce à cette librairie nous pouvons faire des opérations sur ces vecteurs. Par exemples si on veut calculer le carré de chaque élément de ce vecteur on utilise

# %%
# multiplication terme à terme:
print(a*a)

# %% [markdown]
# `np.linspace()` est une fonction utilisée pour générer une séquence d'une dimension d'éléments équidistants entre deux points. La syntaxe de base de la fonction est la suivante : `np.linspace(start, stop, num)` où `start` représente le premier élément, `stop` représente le dernier élément et `num` représente le nombre des éléments souhaités.

# %% [markdown]
# Par exemple, pour générer $5$ éléments équidistants entre $1$ et $5$ on utilise:

# %%
print(np.linspace(0,1,5))

# %% [markdown]
# Pour afficher une figure on utilise la librairie `matplotlib.pyplot`. Par exemple, pour tracer la courbe de la fonction sinus entre $-2$ et $2$ sur $300$ points on utilise le code suivant:

# %%
# utiliser la librairie matplotlib pour tracer des graphes.

x = np.linspace(-2,2,300) # 300 points équidistribués sur [-2,2]

y = np.sin(x) # calcule le vecteur des sinus des points de x.

plt.plot(x,y) # on trace y en fonction de x.

plt.show() #

# %% [markdown]
# Pour tracer sur la même figure la courbe de la fonction sinus en vert et la courbe de la fonction cosinus en rouge on utilise

# %%
# utiliser la librairie matplotlib pour tracer des graphes.

x = np.linspace(-2,2,300) # 300 points équidistribués sur [-2,2]

y = np.sin(x) # calcule le vecteur des sinus des points de x.
z = np.cos(x) # calcule le vecteur des cosinus des points de x.

plt.plot(x, y, color="green") # on trace y en fonction de x.
plt.plot(x, z, color="red") # on trace y en fonction de x.

plt.show()

# %% [markdown]
# Pour ajouter sur le graphique les points de coordonnées `(-1, -0.3), (-0.5, 0), (0, 1), (0.5, 1.25)` on crée deux listes: une liste qui contient les abscisses `A` et une autre qui contient les ordonnées `B`.
# ~~~py
# >>> A = [-1, -0.5, 0, 0.5]
# >>> B = [-0.3, 0, 1, 0.5]
# ~~~
# et puis en trace `B` en fonction de `A` à l'aide de la fonction `plot()` en spécifiant que `linstyle=''` (pour ne pas tracer une courbe) et `marker='x'` afin que les points aient une forme de 'x'.
# ~~~py
# >>> plt.plot(A, B, marker='x', linestyle="")
# ~~~

# %% [markdown]
# **<font color="red">Question: </font>** Tracer sur un même graphique, les deux courbes de `cos` (couleur rouge) et `sin` (couleur verte) sur l'intervalle $[-3, 3]$ en prennant $500$ points pour avoir des courbes lisses. Sur ce même graphique, ajouter les points de coordonnées `(-1, -0.3), (-0.5, 0), (0, 1), (0.5, 1.25)` ayant la forme 'x' et les colorer en bleu.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Génération des données pour les courbes sin et cos
x = np.linspace(-2, 2, 300)  
y = np.sin(x)  
z = np.cos(x)  

# Coordonnées des points supplémentaires
A = [-1, -0.5, 0, 0.5] 
B = [-0.3, 0, 1, 1.25]  

# Tracé des courbes
plt.plot(x, y, color="green", label="sin(x)")  
plt.plot(x, z, color="red", label="cos(x)")    

# Ajout des points supplémentaires
plt.plot(A, B, marker='x', linestyle="", color="blue", label="Points (x)")

# Ajout d'une légende pour identifier les courbes et points
plt.legend()

# Affichage du graphique
plt.show()

# %% [markdown]
# #### Générateurs de nombres aléatoires.

# %% [markdown]
# On utilise la librairie numpy pour avoir accès à des générateurs de nombres aléatoires.

# %% [markdown]
# La fonction `np.random.randint(a,b)` renvoie un nombre entier choisi aléatoirement et uniformément entre `a` et `b-1`.

# %%
# on affiche 5 nombres entiers choisis aléatoirement entre 1 et 9.
for i in range(5):
    X = np.random.randint(1,10)
    print(X)
# Out:
# 3
# 5
# 6
# 3
# 2

# %% [markdown]
# La fonction `np.random.rand(n)` renvoie une liste de taille $n$ qui contient des nombres (réels) choisis aléaoirement et uniformément entre $0$ et $1$.

# %%
# on affiche 5 nombres réels choisis aléatoirement entre 0 et 1.
liste = np.random.rand(5)
print(liste)
# Out:
# [0.84143876 0.76097179 0.25023984 0.51973587 0.06774491]

# %% [markdown]
# ## Partie <span style="font-family: 'Times New Roman';">II</span> - Méthode de Monte-Carlo <font color="red">(partie importante)</font>.

# %% [markdown]
# **<font color = 'blue'>Rappel:</font> Principe de la méthode de Monte-Carlo**
#
# En général, le problème qu'on essaie de résoudre à l'aide de les méthodes de Monte-Carlo est celui de l'estimation d'une valeur inconnue $\mu$. Pour le faire, on adopte une démarche aléatoire où l'on peut trouver une variable aléatoire $X$ et une fonction $f$ telles que l'espérance de $f(X)$ est égale à $\mu$.
# $$ \mathbb{E}[f(X)] = \mu $$
# Ensuite, on génère un échantillon de $n$ variables aléatoires indépendantes qui ont la même loi que la variable $X$. On estime alors la valeur de l'espérance $\mu$ en utilisant la moyenne empirique des $f(X_i)$ que l'on note $\mu_n$.
# $$ \mu_n = \frac{f(X_1)+\cdots, f(X_n)}{n} $$
# On dit alors que $\mu_n$ est une approximation de la valeur de $\mu$, dans le sens où elle converge vers $\mu$
# $$ \mu_n = \frac{f(X_1)+\cdots+f(X_n)}{n} \rightarrow \mathbb{E}[f(X)] = \mu $$

# %% [markdown]
# **<font color="red">Question: </font>** Quel théorème en probabilités nous assure que la méthode de Monte-Carlo marche bien ?

# %% [markdown]
# ### <font color = 'blue'>Exercice 1:</font> Monte-Carlo pour l'estimation de $\mathbb E(U^2)$ où $U$ est une variable aléatoire uniforme sur $[0,1]$.

# %% [markdown]
# On considère $U$ une variable aléatoire uniforme sur l'intervalle $[0,1]$, ça veut dire par exemple, que la probabilité que $U$ appartienne à l'intervalle $[a,b] \subset [0,1]$ est tout simplement égale à la longueur de l'intervalle $[a,b]$ sur la longueur de $[0,1]$, c'est à dire $\mathbb{P}(U\in[a,b]) = b-a$.
#
# On sait alors, intuitivement que l'espérance de variable aléatoire uniforme est $0.5$, cependant la valeur de $\mathbb{E}[U^2]$ n'est pas très intuitive. Ainsi, on propose de l'approximer à l'aide de la méthode de Monte-Carlo.
#
# Dans ce cas, on veut approcher la valeur de $\mu = \mathbb{E}[f(U)]$ où $f$ est la fonction $f(x) = x^2$. Pour le faire on doit générer aléatoirement $n$ valeurs $U_1, \cdots, U_n$ dans l'intervalle $[0,1]$ et calculer la moyenne empirique
# $$ \mu_n = \frac{U_1^2 + \cdots +  U_n^2}{n} $$

# %% [markdown]
# **<font color="red">Question: </font>** Ecrire une fonction `carre()` qui prend en argument un nombre $x$ et qui renvoie son carré.

# %%
def carre(x):
    # à compléter

# %% [markdown]
# **<font color="red">Question: </font>** Ecrire une fonction `generer_valeurs()` qui prend en argument un entier $n$ et qui renvoie une liste de $n$ valeurs tirées aléatoirement et uniformément de l'intervalle $[0,1]$.
#
# *Indication: utiliser la méthode `np.random.rand()`*

# %%
def generer_valeurs(n):
    # à compléter

# %% [markdown]
# **<font color="red">Question: </font>** En utilisant ces deux fonctions, créer une fonction `Monte_Carlo()` qui prend en argument un entier $n$ et qui calcule la moyenne empirique $\mu_n = \frac{U_1^2+\cdots+U_n^2}{n}$.

# %%
def Monte_Carlo(n):
    # à compléter

# %% [markdown]
# **<font color="red">Question: </font>** Tester la fonction pour $n=600$ et vérifier que vous obtenez une valeur approchée de $\frac{1}{3}$.

# %% [markdown]
# ### <font color = 'blue'>Exercice 2:</font> Point fixe d'une permutation
#
# - **<font color="red">Question: </font>** Ecrire une fonction qui prend en argument un entier $m$ et qui génère une permutation aléatoire sur $(1,\ldots,m)$. C'est à dire, il faut renvoyer une liste qui contient les valeurs $1$ jusqu'à $m$ mais pas forcément dans le bon ordre.
# *Indication: utiliser la fonction `np.random.shuffle()`. Voir la documentation [ici](https://numpy.org/doc/stable/reference/random/generated/numpy.random.shuffle.html).

# %% [markdown]
# - **<font color="red">Question: </font>** Pour $m = 5$, calculer avec la méthode de Monte-Carlo la probabilité que le premier élément de la permutation soit égal à $1$. C'est à dire la probabilité qu'une permutation aléatoire $\sigma$ laisse $1$ comme un point fixe $\sigma(1)=1$.
#
# *Indication: Si on considére une variable aléatoire uniforme $\sigma$ sur l'ensemble des permutation $\mathfrak{S}_m$, on veut calculer la probabilité de l'événement $\{\sigma(1)=1\}$. Pour le faire, on considère la fonction $f:\mathfrak{S}_m \rightarrow \{0,1\}$ qui à chaque permutation $\sigma\in \mathfrak{S}_m$ associe la valeur $1$ si $\sigma(1)=1$ et $0$ sinon. On peut remarquer que $$ \mathbb{P}(\sigma(1)=1) = \mathbb{E}[f(\sigma)] $$ ainsi l'idée sera de générer $n$ permutations $\sigma_1,\cdots, \sigma_n$ de l'ensemble $\{1,\cdots, m\}$ et calculer $$ \frac{f(\sigma_1)+\cdots+f(\sigma_n)}{n} $$ d'après le principe de Monte-Carlo, cette valeur devra approché la probabilité souhaitée.*

# %% [markdown]
# **<font color="red">Question: </font>** Vérifier que vous avez bien trouvé une valeur approchée de $1/5$. En général, si on choisi aléatoirement une permutation de l'ensemble $\{1,\cdots,m\}$, la probabilité que $\sigma(1)=1$ est égale à $1/m$. Montrer rigoureusement ce résultat. (*Ecrire la réponse dans la cellule Markdown suivante*).

# %% [markdown]
# ### <font color = 'blue'>Exercice 3:</font> Une loi non uniforme sur les entiers de $1$ à $m$
# - **<font color="red">Question: </font>** On veut calculer une probabilité sur l'ensemble $\{1,\ldots,m\}$ telle que la probabilité $\mathbb P(\{i\})$ est proportionnelle à $i$. C'est à dire on suppose qu'il existe une constante $c$ telle que
# $$ P(\{i\}) = c\times i \quad \forall i\in \{1,\ldots,m\} $$
#  Montrer que $\mathbb P(\{i\}) = \frac{i}{\sum_{i = 1}^m i}$.

# %% [markdown]
# On considère maintenant un nombre tiré aléatoirement de $\{1,\cdots,m\}$ sous cette probabilité, c'est à dire une  variable aléatoire $X$ dont la loi est $$\forall k \in \{1,\cdots,m\} \quad \mathbb{P}(X=k)=\frac{k}{\sum_{i=1}^{m}i}$$

# %% [markdown]
# - **<font color="red">Question: </font>** Ecrire une fonction qui prend en argument un entier $m$ et qui tire aléatoirement un nombre $X$ dans $\{1,\ldots,m\}$ sous cette probabilité.

# %% [markdown]
# - **<font color="red">Question: </font>** Pour $m=9$ estimer par la méthode de Monte-Carlo la moyenne du nombre aléatoire tirée sous cette probabilité, c'est à dire $\mathbb{E}[X]$.

# %% [markdown]
# - **<font color="red">Question: </font>** Calculer rigoureusement la valeur de $\mathbb{E}[X]$ en fonction de $m$ et comparer le résultat obtenu avec la question précédente.

# %% [markdown]
# ### <font color = 'blue'>Exercice 4:</font> Analyse de l'algorithme Quicksort
# On rappelle que QuickSort($A$) pour $A$ un ensemble d'éléments comparables est l'algorithme de tri suivant (on suppose dans notre cas que $A$ est un ensemble, donc sans répétitions):
# 1. Si la longueur de $A$ est nulle, retourner $A$.
# 2. Choisir un élément aléatoirement $p \in A$, appelé élément pivot et construire les ensembles $G$ et $D$ tels que $G$ contient tous les éléments qui sont strictement plus grand que $p$, et $D$ contient les éléments qui sont strictement plus petit que $p$.
# 3. Renvoyer la concaténation [QuickSort($G$), p, QuickSort($D$)].
#
#
# Vous trouverez [ici](https://www.youtube.com/watch?v=8hEyhs3OV1w) une jolie visualisation de l'algorithme Quicksort.

# %% [markdown]
# - **<font color="red">Question: </font>** Implémenter une fonction `quicksort` qui prend en argument une liste $A$ et qui renvoie la liste des éléments de $A$ bien ordonnés grâce à l'algorithme Quicksort décrit au dessus.
#
# *Indication: pour choisir le pivot, on peut d'abord choisir aléatoirement un indice $i$ (entier) entre $0$ et `len(A)` à l'aide de la fonction `np.random.randint()` et puis on sélectionne l'élément d'indice $i$, c'est à dire $L[i]$ qui sera notre pivot.*

# %%
def quicksort(A):
    #  à compléter

# %% [markdown]
# - **<font color="red">Question: </font>** Modifier la fonction précédente en écrivant une nouvelle fonction `quicksort_comp` qui calcule et renvoie le nombre de comparaisons effectuées dans l'algorithme.

# %%
def quicksort_comp(A):
    # à compléter

# %% [markdown]
# - **<font color="red">Question: </font>** A l'aide de la fonction `quicksort_comp` calculer le nombre de comparaisons à effectuer pour trier une liste $A$ de taille $m=10$, $m=40$ et $m=80$.

# %% [markdown]
# Notons $X$ la variable aléatoire qui nous donne le nombre de comparaisons à effectuer pour trier une liste de taille $m$ à l'aide de l'algorithme Quicksort.

# %% [markdown]
# - **<font color="red">Question: </font>** Ecrire une fonction `estim()` qui prend en argument un entier `m` qui représente la taille d'une liste qu'on va trier et qui estime la moyenne $\mathbb{E}[X]$ et la variance $Var[X]$ de la variable aléatoire $X$ en utilisant la méthode de Monte-Carlo.

# %% [markdown]
#  La valeur théorique de l'espérance de $X$ est donnée par la formule suivante:
# $$\mathbb{E}[X]=\sum_{i = 1}^{m-1} \sum_{j = i+1}^m \frac{2}{j-i+1}$$

# %% [markdown]
# - **<font color="red">Question (bonus): </font>** Démontrer cette formule.

# %% [markdown]
# - **<font color="red">Question: </font>** Ecrire une fonction `esp()` qui prend en argument un entier `m` et qui renvoie la valeur de cette somme en $m$.

# %% [markdown]
# - **<font color="red">Question: </font>** A l'aide de la fonction `estim()` comparer les valeurs expérimentales et les valeurs théoriques pour l'espérance de $X$. On peut prendre $m = 10, 40, 80$.

# %% [markdown]
# Afin de montrer que l'algorithme Quicksort a une compléxité en $O(m\log(m))$, où $m$ est la taille de la liste à trier, on souhaite montrer l'inégalité suivante:
# $$ \mathbb{E}[X] \leq 2 m \log(m) $$
#
# - **<font color="red">Question: </font>** A l'aide de la fonction `esp()` tracer en bleu la courbe qui représente $\mathbb{E}[X]$ en fonction de `m` et en rouge la courbe qui représente la fonction $2m\log(m)$ pour des valeurs de `m` entre $1$ et $50$.

# %% [markdown]
# *Indication: on peut utiliser la fonction `np.log` pour le calcul du logarithme et on peut utiliser `np.arange()` pour générer une liste de nombres de $1$ jusqu'à $50$.*

# %% [markdown]
# - **<font color="red">Question: </font>** Commenter.

# %% [markdown]
# ## Partie <span style="font-family: 'Times New Roman';">III</span> - Intervalles de confiance <font color="red">(partie importante)</font>.

# %% [markdown]
# Etant donné des variables aléatoires $X_1,\cdots, X_n$ indépendantes et qui ont la même loi de $X$ telles que $\mathbb{E}[X] = \mu$ et $Var(X) = \sigma^2$. On sait d'après ce qui précède que
# $$ \mu_n = \frac{X_1+\cdots+X_n}{n}\rightarrow \mu $$
#
# Il faut bien comprendre que $\mu_n$ n'est qu'une apporximation de $\mu$, ainsi afin de quantifier l'erreur commise lors cette approximation, on introduit la notion des intervalles de confiance.
#
# Un intervalle de confiance $I_\alpha$ de niveau de confiance $\alpha \in [0,1]$ est un intervalle (asymptotique) tel que $$\mathbb{P}(\mu\in I_\alpha) = \alpha.$$ Par exemple si $\alpha = 0.95$, l'intervalle $I_\alpha$ signifie que : nous sommes confiants avec une probabilité (ou un niveau de confiance) $95\%$ que la vraie valeur de $\mu$ appartient à $I_\alpha$.

# %% [markdown]
# #### Intervalle de confiance dans le cas où la variance $\sigma^2$ est connue.

# %% [markdown]
# Dans le cas où la valeur de la variance $\sigma^2$ et connue, mais que la valeur de l'espérance est inconnue, on propose de l'estimer et de lui donner un certain intervalle de confiance. On donne l'intervalle de confiance $I_\alpha$ suivant:
# $$ I_\alpha = \left[\mu_n - q_\left(\frac{\alpha+1}{2}\right)\frac{\sigma}{\sqrt{n}}, \mu_n + q_\left(\frac{\alpha+1}{2}\right)\frac{\sigma}{\sqrt{n}}\right] $$
#
# C'est à dire qu'on a
# $$\mathbb{P}\left(\mu\in\left[\mu_n - q_\left(\frac{\alpha+1}{2}\right)\frac{\sigma}{\sqrt{n}}, \mu_n + q_\left(\frac{\alpha+1}{2}\right)\frac{\sigma}{\sqrt{n}}\right]\right) = \alpha $$

# %% [markdown]
# Pour tout $\beta\in [0,1]$, on peut calculer la valeur de $q_\beta$ grâce au code suivant (par exemple on prend $\beta = 0.8$)
# ~~~py
# >>> from scipy.stats import norm
# >>> beta = 0.8
# >>> q = norm.ppf(beta)
# >>> print(q)
# 0.8416212335729143
# ~~~

# %% [markdown]
# - **<font color="red">Question: </font>** Calculer la valeur de $q$ pour avoir un intervalle de confiance à $95\%$ de confiance.

# %% [markdown]
# - **<font color="red">Question: </font>** Que peut-on dire que l'intervalle de confiance lorsque le nombre des échantillons $n$ devient très grand ?

# %% [markdown]
# #### Intervalle de confiance dans le cas où la variance $\sigma^2$ est inconnue.

# %% [markdown]
# En général, la valeur de la variance $\sigma^2$ est aussi inconnue, et il faut donc l'estimer. Par conséquence la forme de l'intervalle de confiance change aussi. Pour la trouver, il faut d'abord calculer l'estimateur de $\sigma^2$ que l'on notera $\sigma_n^2$ et est définit par
# $$ \sigma_n^2 = \frac{1}{n-1}\sum_{i=1}^n \left(X_i - \mu_n\right)^2 $$
# où
# $$ \mu_n = \frac{X_1+\cdots+X_n}{n}  $$
#
# L'intervalle de confiance au niveau $\alpha$ est donnée alors par une formule légèrement differente:
# $$ I_\alpha = \left[\mu_n - t_\left(\frac{\alpha+1}{2}, n-1\right)\frac{\sigma_n}{\sqrt{n}}, \mu_n + t_\left(\frac{\alpha+1}{2}, n-1\right)\frac{\sigma_n}{\sqrt{n}}\right] $$
# C'est à dire que
# $$\mathbb{P}\left(\mu\in\left[\mu_n - t_\left(\frac{\alpha+1}{2}, n-1\right)\frac{\sigma_n}{\sqrt{n}}, \mu_n + t_\left(\frac{\alpha+1}{2}, n-1\right)\frac{\sigma_n}{\sqrt{n}}\right]\right) = \alpha $$

# %% [markdown]
# Pour tout $\beta\in [0,1]$ et tout entier $m$, on peut calculer la valeur de $t_{(\beta, m)}$ grâce au code suivant (par exemple on prend $\beta = 0.8$ et $m=20$)
# ~~~py
# >>> from scipy.stats import t
# >>> beta = 0.8
# >>> m = 20
# >>> q = t.ppf(beta, m)
# >>> print(q)
# 0.8599644388738727
# ~~~

# %% [markdown]
# - **<font color="red">Question: </font>** Sachant que la taille de l'échantillon est $n=500$, calculer la valeur de $t$ pour avoir un intervalle de confiance à $95\%$ de confiance.

# %% [markdown]
# ### <font color = 'blue'>Exercice 4:</font> Intervalle de confiance pour $\pi$

# %% [markdown]
# En considère un carré de côté $1$ et un quart de disque inscrit dans ce carré. Si l'on tire un point au hasard dans ce carré, la probabilité que ce point soit dans le quart de disque est :
# $$
# \frac{\textrm{aire du quart de disque}}{\textrm{aire du carré}}.
# $$
# Ce rapport vaut $\displaystyle \frac{\pi}{4}$. Une façon de calculer $\pi$ consiste donc à tirer beaucoup de points au hasard dans le carré et à calculer la proportion de points qui tombent dans le quart de disque. Cette proportion multipliée par 4 donne une approximation de $\pi$.

# %% [markdown]
# - **<font color="red">Question: </font>** Ecrire une fonction `montecarlo_pi` qui prend en paramètre un entier `n` et calcule une approximation de $\pi$ selon la méthode décrite plus haut en utilisant `n` points. Cette fonction affichera également une représentation graphique des points tirés (avec une couleur différente selon qu'ils sont ou non dans le quart de disque). Indication : Tirer un point au hasard revient à tirer deux coordonnées au hasard. En utilisant cette fonction, donner une approximation de $\pi$ en prennant $n = 10^4$.

# %% [markdown]
# - **<font color="red">Question: </font>** Sachant que la valeur de la variance $\sigma^2$ des variables aléatoires considérées est inconnue (puisque ça dépend de $\pi$ que l'on souhaite estimer). Déterminer un intervalle de confiance à $97\%$.
